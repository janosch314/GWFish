# %%
import numpy as np
import pandas as pd
import GWFish.modules as gw
import pickle
import tools

# %%
waveform = 'IMRPhenomXPHM'

# %%
events = np.loadtxt('../GSSI/PHD Projects/GWTC_analysis/' + 'info/' + 'events_with_priors_%s.txt' %waveform, dtype=str)
with open('../GSSI/PHD Projects/GWTC_analysis/' + 'info/' + 'detectors_dictionary.pkl', 'rb') as f:
    detectors = pickle.load(f)

# %%
estimator = 'median'
fisher_parameters = ['chirp_mass', 'mass_ratio', 'luminosity_distance', 'dec', 'ra', 'theta_jn', 'psi', 'phase', 
            'geocent_time', 'a_1', 'a_2', 'tilt_1', 'tilt_2', 'phi_12', 'phi_jl']
#fisher_parameters = ['mass_1', 'mass_2', 'luminosity_distance', 'dec', 'ra', 'theta_jn', 'psi', 'phase', 
#            'geocent_time', 'a_1', 'a_2', 'tilt_1', 'tilt_2', 'phi_12', 'phi_jl']
tools.gwfish_analysis('../GSSI/PHD Projects/GWTC_analysis/yaml/', '../GSSI/PHD Projects/GWTC_analysis/injections/', events, waveform, estimator,
                    detectors, fisher_parameters, 'gwtc_results')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# gw_params: chirp_mass             1.848387e+01
# mass_ratio             5.379655e-01
# luminosity_distance    9.740950e+02
# dec                   -1.304342e-02
# ra                     2.863215e+00
# theta_jn               1.765304e+00
# psi                    1.526003e+00
# phase                  3.132095e+00
# geocent_time           1.128679e+09
# a_1                    3.897193e-01
# a_2                    4.472236e-01
# tilt_1                 1.188890e+00
# tilt_2                 1.369748e+00
# phi_12                 3.135393e+00
# phi_jl                 3.132237e+00
# Name: 0, dtype: float64
# after gw_params: chirp_mass             1.848387e+01
# mass_ratio             5.379655e-01
# luminosity_distance    9.740950e+02
# dec                   -1.304342e-02
# ra                     2.863215e+00
# theta_jn               1.765304e+00
# psi                    1.526003e+00
# phase                  3.132095e+00
# ...
